# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# 
train=pd.read_csv('../../data/Titanic/train.csv')
# test=pd.read_csv('../../data/Titanic/test.csv')
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 检查多少为空
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
train['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=train,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
train.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
train[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=train,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
pd.crosstab(train.Pclass,train.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row0_col0 {
#             background-color:  #ffff66;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row0_col1 {
#             background-color:  #cee666;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row1_col1 {
#             background-color:  #ffff66;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row1_col2 {
#             background-color:  #ffff66;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row2_col0 {
#             background-color:  #60b066;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row2_col1 {
#             background-color:  #dfef66;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row2_col2 {
#             background-color:  #90c866;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row3_col0 {
#             background-color:  #008066;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row3_col1 {
#             background-color:  #008066;
#         }    #T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row3_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row0_col0" class="data row0 col0" >80</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row0_col1" class="data row0 col1" >136</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row1_col0" class="data row1 col0" >97</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row1_col1" class="data row1 col1" >87</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row2_col0" class="data row2 col0" >372</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row2_col1" class="data row2 col1" >119</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566level0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row3_col0" class="data row3 col0" >549</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row3_col1" class="data row3 col1" >342</td>
#         <td id="T_14f4b0d4_5f64_11e8_aeed_c4b30197a566row3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=train,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([train.Sex,train.Survived],train.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col0 {
#             background-color:  #ffff66;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col1 {
#             background-color:  #ffff66;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col2 {
#             background-color:  #f1f866;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col3 {
#             background-color:  #ffff66;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col0 {
#             background-color:  #96cb66;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col1 {
#             background-color:  #a3d166;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col2 {
#             background-color:  #f1f866;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col3 {
#             background-color:  #cfe766;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col0 {
#             background-color:  #a7d366;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col1 {
#             background-color:  #85c266;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col2 {
#             background-color:  #6eb666;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col3 {
#             background-color:  #85c266;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col0 {
#             background-color:  #cde666;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col1 {
#             background-color:  #f0f866;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col2 {
#             background-color:  #ffff66;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col3 {
#             background-color:  #f7fb66;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col0 {
#             background-color:  #008066;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col1 {
#             background-color:  #008066;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col2 {
#             background-color:  #008066;
#         }    #T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col0" class="data row0 col0" >3</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col1" class="data row0 col1" >6</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col2" class="data row0 col2" >72</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col0" class="data row1 col0" >91</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col1" class="data row1 col1" >70</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col2" class="data row1 col2" >72</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row1_col3" class="data row1 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col0" class="data row2 col0" >77</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col1" class="data row2 col1" >91</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col2" class="data row2 col2" >300</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row2_col3" class="data row2 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col0" class="data row3 col0" >45</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col1" class="data row3 col1" >17</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col2" class="data row3 col2" >47</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566level1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col0" class="data row4 col0" >216</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col1" class="data row4 col1" >184</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col2" class="data row4 col2" >491</td>
#         <td id="T_a67ac7b0_5f66_11e8_9c53_c4b30197a566row4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=train)
plt.show()

# %%
print('Oldest Passenger was of:',train['Age'].max(),'Years')
print('Youngest Passenger was of:',train['Age'].min(),'Years')
print('Average Age on the ship:',train['Age'].mean(),'Years')
# Out:
# ('Oldest Passenger was of:', 80.0, 'Years')
# ('Youngest Passenger was of:', 0.42, 'Years')
# ('Average Age on the ship:', 29.69911764705882, 'Years')

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=train,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=train,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
train['Initial']=0
for i in train:
    train['Initial']=train.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
#Checking the Initials with the Sex
pd.crosstab(train.Initial,train.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col0 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col1 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col2 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col3 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col4 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col5 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col6 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col7 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col8 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col9 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col10 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col11 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col12 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col13 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col14 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col15 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col16 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col0 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col1 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col2 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col3 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col4 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col5 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col6 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col7 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col8 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col9 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col10 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col11 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col12 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col13 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col14 {
#             background-color:  #ffff66;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col15 {
#             background-color:  #008066;
#         }    #T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_94f52efd_6337_11e8_8aed_c4b30197a566" >
# <thead>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Countess</th>
#         <th class="col_heading level0 col3" >Don</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_94f52efd_6337_11e8_8aed_c4b30197a566level0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col0" class="data row0 col0" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col1" class="data row0 col1" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col2" class="data row0 col2" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col3" class="data row0 col3" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col4" class="data row0 col4" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col5" class="data row0 col5" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col6" class="data row0 col6" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col7" class="data row0 col7" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col8" class="data row0 col8" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col9" class="data row0 col9" >182</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col10" class="data row0 col10" >2</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col11" class="data row0 col11" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col12" class="data row0 col12" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col13" class="data row0 col13" >125</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col14" class="data row0 col14" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col15" class="data row0 col15" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_94f52efd_6337_11e8_8aed_c4b30197a566level0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col0" class="data row1 col0" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col1" class="data row1 col1" >2</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col2" class="data row1 col2" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col3" class="data row1 col3" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col4" class="data row1 col4" >6</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col5" class="data row1 col5" >1</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_col6" class="data row1 col6" >0</td>
#         <td id="T_94f52efd_6337_11e8_8aed_c4b30197a566row1_c

# %%
train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
train.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
train.loc[(train.Age.isnull())&(train.Initial=='Mr'),'Age']=33
train.loc[(train.Age.isnull())&(train.Initial=='Mrs'),'Age']=36
train.loc[(train.Age.isnull())&(train.Initial=='Master'),'Age']=5
train.loc[(train.Age.isnull())&(train.Initial=='Miss'),'Age']=22
train.loc[(train.Age.isnull())&(train.Initial=='Other'),'Age']=46

# %%
train.Age.isnull().any()
# Out:
# True

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
train[train['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
train[train['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=train)
plt.show()

# %%
pd.crosstab([train.Embarked,train.Pclass],
            [train.Sex,train.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col0 {
#             background-color:  #fcfe66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col1 {
#             background-color:  #d2e866;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col2 {
#             background-color:  #f2f866;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col3 {
#             background-color:  #d8ec66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col4 {
#             background-color:  #e8f466;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col0 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col1 {
#             background-color:  #f9fc66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col2 {
#             background-color:  #fcfe66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col3 {
#             background-color:  #fbfd66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col4 {
#             background-color:  #fbfd66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col0 {
#             background-color:  #e6f266;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col1 {
#             background-color:  #f0f866;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col2 {
#             background-color:  #eef666;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col3 {
#             background-color:  #e8f466;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col4 {
#             background-color:  #edf666;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row3_col0 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row3_col1 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row3_col2 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row3_col3 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row3_col4 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row4_col0 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row4_col1 {
#             background-color:  #fefe66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row4_col2 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row4_col3 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row4_col4 {
#             background-color:  #ffff66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row5_col0 {
#             background-color:  #e3f166;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row5_col1 {
#             background-color:  #e6f266;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row5_col2 {
#             background-color:  #ecf666;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row5_col3 {
#             background-color:  #f8fc66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row5_col4 {
#             background-color:  #ebf566;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row6_col0 {
#             background-color:  #f9fc66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row6_col1 {
#             background-color:  #cde666;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row6_col2 {
#             background-color:  #e4f266;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row6_col3 {
#             background-color:  #bede66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row6_col4 {
#             background-color:  #dbed66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row7_col0 {
#             background-color:  #edf666;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row7_col1 {
#             background-color:  #bdde66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row7_col2 {
#             background-color:  #d3e966;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row7_col3 {
#             background-color:  #dcee66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row7_col4 {
#             background-color:  #d1e866;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row8_col0 {
#             background-color:  #52a866;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row8_col1 {
#             background-color:  #dcee66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row8_col2 {
#             background-color:  #81c066;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row8_col3 {
#             background-color:  #b0d866;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row8_col4 {
#             background-color:  #9acc66;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row9_col0 {
#             background-color:  #008066;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row9_col1 {
#             background-color:  #008066;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row9_col2 {
#             background-color:  #008066;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row9_col3 {
#             background-color:  #008066;
#         }    #T_c0e5e773_6279_11e8_8475_c4b30197a566row9_col4 {
#             background-color:  #008066;
#         }</style>
# <table id="T_c0e5e773_6279_11e8_8475_c4b30197a566" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Sex</th>
#         <th class="col_heading level0 col0" colspan=2>female</th>
#         <th class="col_heading level0 col2" colspan=2>male</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Survived</th>
#         <th class="col_heading level1 col0" >0</th>
#         <th class="col_heading level1 col1" >1</th>
#         <th class="col_heading level1 col2" >0</th>
#         <th class="col_heading level1 col3" >1</th>
#         <th class="col_heading level1 col4" ></th>
#     </tr>    <tr>
#         <th class="index_name level0" >Embarked</th>
#         <th class="index_name level1" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c0e5e773_6279_11e8_8475_c4b30197a566level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#         <th id="T_c0e5e773_6279_11e8_8475_c4b30197a566level1_row0" class="row_heading level1 row0" >1</th>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col0" class="data row0 col0" >1</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col1" class="data row0 col1" >42</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col2" class="data row0 col2" >25</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col3" class="data row0 col3" >17</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row0_col4" class="data row0 col4" >85</td>
#     </tr>    <tr>
#         <th id="T_c0e5e773_6279_11e8_8475_c4b30197a566level1_row1" class="row_heading level1 row1" >2</th>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col0" class="data row1 col0" >0</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col1" class="data row1 col1" >7</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col2" class="data row1 col2" >8</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col3" class="data row1 col3" >2</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row1_col4" class="data row1 col4" >17</td>
#     </tr>    <tr>
#         <th id="T_c0e5e773_6279_11e8_8475_c4b30197a566level1_row2" class="row_heading level1 row2" >3</th>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col0" class="data row2 col0" >8</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col1" class="data row2 col1" >15</td>
#         <td id="T_c0e5e773_6279_11e8_8475_c4b30197a566row2_col2" class=

# %%
sns.factorplot('Embarked','Survived',data=train)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=train,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=train,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=train,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=train,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=train)
plt.show()

# %%
train['Embarked'].fillna('S',inplace=True) #用S填充空值
train.Embarked.isnull().any()# Finally No NaN values
# Out:
# False

# %%
pd.crosstab([train.SibSp],train.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_396e4e87_627b_11e8_9030_c4b30197a566row0_col0 {
#             background-color:  #008066;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row0_col1 {
#             background-color:  #008066;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row1_col0 {
#             background-color:  #c4e266;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row1_col1 {
#             background-color:  #77bb66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row2_col0 {
#             background-color:  #f9fc66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row2_col1 {
#             background-color:  #f0f866;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row3_col0 {
#             background-color:  #fbfd66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row3_col1 {
#             background-color:  #fbfd66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row4_col0 {
#             background-color:  #f9fc66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row4_col1 {
#             background-color:  #fcfe66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row5_col0 {
#             background-color:  #ffff66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row5_col1 {
#             background-color:  #ffff66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row6_col0 {
#             background-color:  #fefe66;
#         }    #T_396e4e87_627b_11e8_9030_c4b30197a566row6_col1 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_396e4e87_627b_11e8_9030_c4b30197a566" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SibSp</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_396e4e87_627b_11e8_9030_c4b30197a566level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row0_col0" class="data row0 col0" >398</td>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row0_col1" class="data row0 col1" >210</td>
#     </tr>    <tr>
#         <th id="T_396e4e87_627b_11e8_9030_c4b30197a566level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row1_col0" class="data row1 col0" >97</td>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row1_col1" class="data row1 col1" >112</td>
#     </tr>    <tr>
#         <th id="T_396e4e87_627b_11e8_9030_c4b30197a566level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row2_col0" class="data row2 col0" >15</td>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row2_col1" class="data row2 col1" >13</td>
#     </tr>    <tr>
#         <th id="T_396e4e87_627b_11e8_9030_c4b30197a566level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row3_col0" class="data row3 col0" >12</td>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row3_col1" class="data row3 col1" >4</td>
#     </tr>    <tr>
#         <th id="T_396e4e87_627b_11e8_9030_c4b30197a566level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row4_col0" class="data row4 col0" >15</td>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row4_col1" class="data row4 col1" >3</td>
#     </tr>    <tr>
#         <th id="T_396e4e87_627b_11e8_9030_c4b30197a566level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row5_col0" class="data row5 col0" >5</td>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row5_col1" class="data row5 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_396e4e87_627b_11e8_9030_c4b30197a566level0_row6" class="row_heading level0 row6" >8</th>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row6_col0" class="data row6 col0" >7</td>
#         <td id="T_396e4e87_627b_11e8_9030_c4b30197a566row6_col1" class="data row6 col1" >0</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=train,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=train,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %%
pd.crosstab(train.SibSp,train.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6816b96e_627b_11e8_ad54_c4b30197a566row0_col0 {
#             background-color:  #008066;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row0_col1 {
#             background-color:  #008066;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row0_col2 {
#             background-color:  #008066;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row1_col0 {
#             background-color:  #7bbd66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row1_col1 {
#             background-color:  #8ac466;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row1_col2 {
#             background-color:  #c6e266;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row2_col0 {
#             background-color:  #f6fa66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row2_col1 {
#             background-color:  #eef666;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row2_col2 {
#             background-color:  #f8fc66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row3_col0 {
#             background-color:  #fafc66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row3_col1 {
#             background-color:  #fdfe66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row3_col2 {
#             background-color:  #fafc66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row4_col0 {
#             background-color:  #ffff66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row4_col1 {
#             background-color:  #ffff66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row4_col2 {
#             background-color:  #f6fa66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row5_col0 {
#             background-color:  #ffff66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row5_col1 {
#             background-color:  #ffff66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row5_col2 {
#             background-color:  #ffff66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row6_col0 {
#             background-color:  #ffff66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row6_col1 {
#             background-color:  #ffff66;
#         }    #T_6816b96e_627b_11e8_ad54_c4b30197a566row6_col2 {
#             background-color:  #fefe66;
#         }</style>
# <table id="T_6816b96e_627b_11e8_ad54_c4b30197a566" >
# <thead>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SibSp</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6816b96e_627b_11e8_ad54_c4b30197a566level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row0_col0" class="data row0 col0" >137</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row0_col1" class="data row0 col1" >120</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row0_col2" class="data row0 col2" >351</td>
#     </tr>    <tr>
#         <th id="T_6816b96e_627b_11e8_ad54_c4b30197a566level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row1_col0" class="data row1 col0" >71</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row1_col1" class="data row1 col1" >55</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row1_col2" class="data row1 col2" >83</td>
#     </tr>    <tr>
#         <th id="T_6816b96e_627b_11e8_ad54_c4b30197a566level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row2_col0" class="data row2 col0" >5</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row2_col1" class="data row2 col1" >8</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row2_col2" class="data row2 col2" >15</td>
#     </tr>    <tr>
#         <th id="T_6816b96e_627b_11e8_ad54_c4b30197a566level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row3_col0" class="data row3 col0" >3</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row3_col1" class="data row3 col1" >1</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row3_col2" class="data row3 col2" >12</td>
#     </tr>    <tr>
#         <th id="T_6816b96e_627b_11e8_ad54_c4b30197a566level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row4_col0" class="data row4 col0" >0</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row4_col1" class="data row4 col1" >0</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row4_col2" class="data row4 col2" >18</td>
#     </tr>    <tr>
#         <th id="T_6816b96e_627b_11e8_ad54_c4b30197a566level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row5_col0" class="data row5 col0" >0</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row5_col1" class="data row5 col1" >0</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row5_col2" class="data row5 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_6816b96e_627b_11e8_ad54_c4b30197a566level0_row6" class="row_heading level0 row6" >8</th>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row6_col0" class="data row6 col0" >0</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row6_col1" class="data row6 col1" >0</td>
#         <td id="T_6816b96e_627b_11e8_ad54_c4b30197a566row6_col2" class="data row6 col2" >7</td>
#     </tr></tbody>
# </table>

# %%
pd.crosstab(train.Parch,train.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_eaa51299_627b_11e8_8a6b_c4b30197a566row0_col0 {
#             background-color:  #008066;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row0_col1 {
#             background-color:  #008066;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row0_col2 {
#             background-color:  #008066;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row1_col0 {
#             background-color:  #cfe766;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row1_col1 {
#             background-color:  #c2e066;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row1_col2 {
#             background-color:  #dbed66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row2_col0 {
#             background-color:  #dfef66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row2_col1 {
#             background-color:  #e1f066;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row2_col2 {
#             background-color:  #e3f166;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row3_col0 {
#             background-color:  #ffff66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row3_col1 {
#             background-color:  #fcfe66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row3_col2 {
#             background-color:  #fefe66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row4_col0 {
#             background-color:  #fefe66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row4_col1 {
#             background-color:  #ffff66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row4_col2 {
#             background-color:  #fefe66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row5_col0 {
#             background-color:  #ffff66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row5_col1 {
#             background-color:  #ffff66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row5_col2 {
#             background-color:  #fdfe66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row6_col0 {
#             background-color:  #ffff66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row6_col1 {
#             background-color:  #ffff66;
#         }    #T_eaa51299_627b_11e8_8a6b_c4b30197a566row6_col2 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_eaa51299_627b_11e8_8a6b_c4b30197a566" >
# <thead>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Parch</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_eaa51299_627b_11e8_8a6b_c4b30197a566level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row0_col0" class="data row0 col0" >163</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row0_col1" class="data row0 col1" >134</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row0_col2" class="data row0 col2" >381</td>
#     </tr>    <tr>
#         <th id="T_eaa51299_627b_11e8_8a6b_c4b30197a566level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row1_col0" class="data row1 col0" >31</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row1_col1" class="data row1 col1" >32</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row1_col2" class="data row1 col2" >55</td>
#     </tr>    <tr>
#         <th id="T_eaa51299_627b_11e8_8a6b_c4b30197a566level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row2_col0" class="data row2 col0" >21</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row2_col1" class="data row2 col1" >16</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row2_col2" class="data row2 col2" >43</td>
#     </tr>    <tr>
#         <th id="T_eaa51299_627b_11e8_8a6b_c4b30197a566level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row3_col0" class="data row3 col0" >0</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row3_col1" class="data row3 col1" >2</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row3_col2" class="data row3 col2" >3</td>
#     </tr>    <tr>
#         <th id="T_eaa51299_627b_11e8_8a6b_c4b30197a566level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row4_col0" class="data row4 col0" >1</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row4_col1" class="data row4 col1" >0</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row4_col2" class="data row4 col2" >3</td>
#     </tr>    <tr>
#         <th id="T_eaa51299_627b_11e8_8a6b_c4b30197a566level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row5_col0" class="data row5 col0" >0</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row5_col1" class="data row5 col1" >0</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row5_col2" class="data row5 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_eaa51299_627b_11e8_8a6b_c4b30197a566level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row6_col0" class="data row6 col0" >0</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row6_col1" class="data row6 col1" >0</td>
#         <td id="T_eaa51299_627b_11e8_8a6b_c4b30197a566row6_col2" class="data row6 col2" >1</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=train,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=train,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.close(2)
plt.show()

# %%
print('Highest Fare was:',train['Fare'].max())
print('Lowest Fare was:',train['Fare'].min())
print('Average Fare was:',train['Fare'].mean())
# Out:
# ('Highest Fare was:', 512.3292)
# ('Lowest Fare was:', 0.0)
# ('Average Fare was:', 32.204207968574636)

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(train[train['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(train[train['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(train[train['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.heatmap(train.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# %%
train_data,test_data=train_test_split(train,test_size=0.3,random_state=0,stratify=train['Survived'])
train_X=train_data[train_data.columns[1:]]
train_Y=train_data[train_data.columns[:1]]
test_X=test_data[test_data.columns[1:]]
test_Y=test_data[test_data.columns[:1]]
X=train[train.columns[1:]]
Y=train['Survived']

# %%
model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
model.fit(train_X,train_Y)
prediction1=model.predict(test_X)
print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,test_Y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-78ba8bb61482> in <module>()
#       1 model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
# ----> 2 model.fit(train_X,train_Y)
#       3 prediction1=model.predict(test_X)
#       4 print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,test_Y))
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: Mr
